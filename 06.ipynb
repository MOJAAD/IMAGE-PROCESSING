# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pic = cv2.imread("E://University-working/openCV python/Udemy - Python for Computer Vision with OpenCV and Deep Learning 2019-9/Computer-Vision-with-Python/DATA/00-puppy.jpg")

# %%
plt.imshow(pic)

# %%
pic = cv2.cvtColor(pic,cv2.COLOR_BGR2RGB)
plt.imshow(pic)

# %%
pic = cv2.cvtColor(pic,cv2.COLOR_BGR2HSV)
plt.imshow(pic)

# %%
pic = cv2.cvtColor(pic,cv2.COLOR_BGR2HLS)
plt.imshow(pic)
